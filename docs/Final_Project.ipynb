# %% [markdown]
# ## Installation

# %%
# !pip install google-generativeai==0.8.4 --no-deps
# !pip install hnswlib==0.7.0 --no-deps
# !pip install tqdm --no-deps
# !pip install fsspec==2024.10.0 --no-deps
# Issue Log: dependency conflict between NumPy and scikit-learn
# !pip install scikit-learn==1.3.2 --no-deps
# !pip install numpy==1.23.5 --no-deps
# Issue Log: NLTK's punkt tokenizer requires additional data files
# !pip install nltk rouge-score
# Out:
# Requirement already satisfied: google-generativeai==0.8.4 in /usr/local/lib/python3.11/dist-packages (0.8.4)
# Requirement already satisfied: hnswlib==0.7.0 in /usr/local/lib/python3.11/dist-packages (0.7.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: fsspec==2024.10.0 in /usr/local/lib/python3.11/dist-packages (2024.10.0)
# Requirement already satisfied: scikit-learn==1.3.2 in /usr/local/lib/python3.11/dist-packages (1.3.2)
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.11/dist-packages (1.23.5)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.11/dist-packages (0.1.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.23.5)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)

# %%
import pandas as pd
import numpy as np
import google.generativeai as genai
import json
import time
import hnswlib
from google.generativeai import GenerativeModel
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity
from google.api_core import exceptions as google_exceptions
from tenacity import retry, stop_after_attempt, wait_exponential, retry_if_exception_type, wait_random_exponential
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer
import nltk

# %% [markdown]
# ## Configuration

# %% [markdown]
# Download NLTK data for BLEU, initialize ROUGE scorer.

# %%
nltk.download('punkt', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)
rouge_scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
# nltk.download('punkt_tab')

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import google.generativeai as genai

GOOGLE_API_KEY = "AIzaSyDac912hYoC4czAPjFan_Ix6SgnVQbqWJA"
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-1.5-flash')
embedding_model = genai.get_model('models/text-embedding-004')

# %% [markdown]
# ## Pre-Processing

# %%
df = pd.read_csv('Customer_Support_Training_Dataset.csv')
df = df.rename(columns={"instruction": "prompt"})
df = df.dropna(subset=["prompt", "response"])
df = df.sample(n=200, random_state=42)

# %% [markdown]
# ## Word Embedding & HNSW Indexing

# %% [markdown]
# An empty dictionary `cache` is declared to cache the result of text embedding, with the primary goal to avoid repeated calculation, optimizing the embedding process.
#
# After resetting the maximum retrying attempt if request failed, the text embedding is performed, followed with HNSW (Hierarchical Navigable Small World, an ANN algorithm), which accelerates vector searching with indexing.

# %%
cached_embeddings = {}

@retry(stop=stop_after_attempt(3), wait=wait_random_exponential(min=1, max=5))
def get_embedding(text):
    if text not in cached_embeddings:
        # Generate & cache embedding vectors
        response = genai.embed_content(
            model='models/text-embedding-004',
            content=text,
            task_type='retrieval_document'
        )
        cached_embeddings[text] = np.array(response['embedding'], dtype=np.float32)
    return cached_embeddings[text]

embeddings = np.array([get_embedding(text) for text in tqdm(df['prompt'])], dtype=np.float32)

# Indexing
dim = embeddings.shape[1]
index = hnswlib.Index(space='cosine', dim=dim)
index.init_index(max_elements=1000, ef_construction=200, M=16)
index.add_items(embeddings, ids=np.arange(len(embeddings)))
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 1/200 [00:00<01:13,  2.69it/s]
#   1%|          | 2/200 [00:00<01:07,  2.94it/s]
#   2%|▏         | 3/200 [00:01<01:05,  3.03it/s]
#   2%|▏         | 4/200 [00:01<01:03,  3.07it/s]
#   2%|▎         | 5/200 [00:01<01:03,  3.09it/s]
#   3%|▎         | 6/200 [00:01<01:02,  3.09it/s]
#   4%|▎         | 7/200 [00:02<01:06,  2.88it/s]
#   4%|▍         | 8/200 [00:02<01:04,  2.96it/s]
#   4%|▍         | 9/200 [00:03<01:35,  2.01it/s]
#   5%|▌         | 10/200 [00:04<01:33,  2.03it/s]
#   6%|▌         | 11/200 [00:04<01:42,  1.84it/s]
#   6%|▌         | 12/200 [00:05<01:38,  1.91it/s]
#   6%|▋         | 13/200 [00:05<01:35,  1.97it/s]
#   7%|▋         | 14/200 [00:06<01:32,  2.01it/s]
#   8%|▊         | 15/200 [00:06<01:30,  2.05it/s]
#   8%|▊         | 16/200 [00:07<01:27,  2.10it/s]
#   8%|▊         | 17/200 [00:07<01:26,  2.11it/s]
#   9%|▉         | 18/200 [00:07<01:25,  2.12it/s]
#  10%|▉         | 19/200 [00:08<01:26,  2.09it/s]
#  10%|█         | 20/200 [00:08<01:25,  2.10it/s]
#  10%|█         | 21/200 [00:09<01:28,  2.02it/s]
#  11%|█         | 22/200 [00:09<01:26,  2.05it/s]
#  12%|█▏        | 23/200 [00:10<01:26,  2.04it/s]
#  12%|█▏        | 24/200 [00:10<01:26,  2.03it/s]
#  12%|█▎        | 25/200 [00:11<01:25,  2.06it/s]
#  13%|█▎        | 26/200 [00:11<01:23,  2.08it/s]
#  14%|█▎        | 27/200 [00:12<01:23,  2.06it/s]
#  14%|█▍        | 28/200 [00:12<01:22,  2.08it/s]
#  14%|█▍        | 29/200 [00:13<01:21,  2.09it/s]
#  15%|█▌        | 30/200 [00:13<01:20,  2.10it/s]
#  16%|█▌        | 31/200 [00:14<01:21,  2.08it/s]
#  16%|█▌        | 32/200 [00:14<01:20,  2.09it/s]
#  16%|█▋        | 33/200 [00:15<01:19,  2.10it/s]
#  17%|█▋        | 34/200 [00:15<01:20,  2.06it/s]
#  18%|█▊        | 35/200 [00:16<01:19,  2.07it/s]
#  18%|█▊        | 36/200 [00:16<01:18,  2.08it/s]
#  18%|█▊        | 37/200 [00:17<01:18,  2.07it/s]
#  19%|█▉        | 38/200 [00:17<01:19,  2.05it/s]
#  20%|█▉        | 39/200 [00:18<01:19,  2.04it/s]
#  20%|██        | 40/200 [00:18<01:18,  2.03it/s]
#  20%|██        | 41/200 [00:19<01:18,  2.02it/s]
#  21%|██        | 42/200 [00:19<01:18,  2.01it/s]
#  22%|██▏       | 43/200 [00:20<01:17,  2.02it/s]
#  22%|██▏       | 44/200 [00:20<01:16,  2.05it/s]
#  22%|██▎       | 45/200 [00:21<01:14,  2.07it/s]
#  23%|██▎       | 46/200 [00:21<01:13,  2.09it/s]
#  24%|██▎       | 47/200 [00:22<01:12,  2.10it/s]
#  24%|██▍       | 48/200 [00:22<01:13,  2.07it/s]
#  24%|██▍       | 49/200 [00:23<01:13,  2.05it/s]
#  25%|██▌       | 50/200 [00:23<01:12,  2.07it/s]
#  26%|██▌       | 51/200 [00:24<01:13,  2.02it/s]
#  26%|██▌       | 52/200 [00:24<01:12,  2.05it/s]
#  26%|██▋       | 53/200 [00:24<01:10,  2.08it/s]
#  27%|██▋       | 54/200 [00:25<01:09,  2.09it/s]
#  28%|██▊       | 55/200 [00:25<01:08,  2.10it/s]
#  28%|██▊       | 56/200 [00:26<01:08,  2.11it/s]
#  28%|██▊       | 57/200 [00:26<01:07,  2.11it/s]
#  29%|██▉       | 58/200 [00:27<01:08,  2.08it/s]
#  30%|██▉       | 59/200 [00:27<01:07,  2.09it/s]
#  30%|███       | 60/200 [00:28<01:07,  2.06it/s]
#  30%|███       | 61/200 [00:28<01:07,  2.05it/s]
#  31%|███       | 62/200 [00:29<01:07,  2.04it/s]
#  32%|███▏      | 63/200 [00:29<01:07,  2.03it/s]
#  32%|███▏      | 64/200 [00:30<01:05,  2.06it/s]
#  32%|███▎      | 65/200 [00:30<01:04,  2.08it/s]
#  33%|███▎      | 66/200 [00:31<01:06,  2.00it/s]
#  34%|███▎      | 67/200 [00:31<01:04,  2.07it/s]
#  34%|███▍      | 68/200 [00:32<01:03,  2.08it/s]
#  34%|███▍      | 69/200 [00:32<01:00,  2.17it/s]
#  35%|███▌      | 70/200 [00:33<01:00,  2.16it/s]
#  36%|███▌      | 71/200 [00:33<00:58,  2.19it/s]
#  36%|███▌      | 72/200 [00:33<00:59,  2.17it/s]
#  36%|███▋      | 73/200 [00:34<00:59,  2.12it/s]
#  37%|███▋      | 74/200 [00:34<00:58,  2.15it/s]
#  38%|███▊      | 75/200 [00:35<00:58,  2.14it/s]
#  38%|███▊      | 76/200 [00:35<00:59,  2.07it/s]
#  38%|███▊      | 77/200 [00:36<00:57,  2.12it/s]
#  39%|███▉      | 78/200 [00:36<00:56,  2.16it/s]
#  40%|███▉      | 79/200 [00:37<00:55,  2.19it/s]
#  40%|████      | 80/200 [00:37<00:54,  2.21it/s]
#  40%|████      | 81/200 [00:38<00:54,  2.18it/s]
#  41%|████      | 82/200 [00:38<00:54,  2.16it/s]
#  42%|████▏     | 83/200 [00:39<00:53,  2.17it/s]
#  42%|████▏     | 84/200 [00:39<00:53,  2.15it/s]
#  42%|████▎     | 85/200 [00:40<00:53,  2.14it/s]
#  43%|████▎     | 86/200 [00:40<00:53,  2.13it/s]
#  44%|████▎     | 87/200 [00:40<00:53,  2.12it/s]
#  44%|████▍     | 88/200 [00:41<00:52,  2.13it/s]
#  44%|████▍     | 89/200 [00:41<00:51,  2.16it/s]
#  45%|████▌     | 90/200 [00:42<00:50,  2.18it/s]
#  46%|████▌     | 91/200 [00:42<00:49,  2.20it/s]
#  46%|████▌     | 92/200 [00:43<00:49,  2.17it/s]
#  46%|████▋     | 93/200 [00:43<00:48,  2.19it/s]
#  47%|████▋     | 94/200 [00:44<00:48,  2.20it/s]
#  48%|████▊     | 95/200 [00:44<00:47,  2.22it/s]
#  48%|████▊     | 96/200 [00:45<00:47,  2.19it/s]
#  48%|████▊     | 97/200 [00:45<00:47,  2.17it/s]
#  49%|████▉     | 98/200 [00:45<00:46,  2.19it/s]
#  50%|████▉     | 99/200 [00:46<00:46,  2.18it/s]
#  50%|█████     | 100/200 [00:46<00:45,  2.20it/s]
#  50%|█████     | 101/200 [00:47<00:45,  2.18it/s]
#  51%|█████     | 102/200 [00:47<00:43,  2.27it/s]
#  52%|█████▏    | 103/200 [00:48<00:43,  2.25it/s]
#  52%|█████▏    | 104/200 [00:48<00:42,  2.25it/s]
#  52%|█████▎    | 105/200 [00:49<00:43,  2.21it/s]
#  53%|█████▎    | 106/200 [00:49<00:42,  2.22it/s]
#  54%|█████▎    | 107/200 [00:50<00:41,  2.22it/s]
#  54%|█████▍    | 108/200 [00:50<00:42,  2.18it/s]
#  55%|█████▍    | 109/200 [00:50<00:41,  2.18it/s]
#  55%|█████▌    | 110/200 [00:51<00:42,  2.12it/s]
#  56%|█████▌    | 111/200 [00:51<00:41,  2.14it/s]
#  56%|█████▌    | 112/200 [00:52<00:41,  2.14it/s]
#  56%|█████▋    | 113/200 [00:52<00:40,  2.13it/s]
#  57%|█████▋    | 114/200 [00:53<00:40,  2.13it/s]
#  57%|█████▊    | 115/200 [00:53<00:40,  2.09it/s]
#  58%|█████▊    | 116/200 [00:54<00:40,  2.10it/s]
#  58%|█████▊    | 117/200 [00:54<00:39,  2.11it/s]
#  59%|█████▉    | 118/200 [00:55<00:38,  2.11it/s]
#  60%|█████▉    | 119/200 [00:55<00:37,  2.15it/s]
#  60%|██████    | 120/200 [00:56<00:37,  2.14it/s]
#  60%|██████    | 121/200 [00:56<00:36,  2.16it/s]
#  61%|██████    | 122/200 [00:57<00:36,  2.12it/s]
#  62%|██████▏   | 123/200 [00:57<00:36,  2.12it/s]
#  62%|██████▏   | 124/200 [00:58<00:35,  2.16it/s]
#  62%|██████▎   | 125/200 [00:58<00:34,  2.15it/s]
#  63%|██████▎   | 126/200 [00:58<00:34,  2.14it/s]
#  64%|██████▎   | 127/200 [00:59<00:33,  2.17it/s]
#  64%|██████▍   | 128/200 [00:59<00:32,  2.19it/s]
#  64%|██████▍   | 129/200 [01:00<00:32,  2.18it/s]
#  65%|██████▌   | 130/200 [01:00<00:32,  2.16it/s]
#  66%|██████▌   | 131/200 [01:01<00:31,  2.18it/s]
#  66%|██████▌   | 132/200 [01:01<00:31,  2.16it/s]
#  66%|██████▋   | 133/200 [01:02<00:30,  2.18it/s]
#  67%|██████▋   | 134/200 [01:02<00:31,  2.12it/s]
#  68%|██████▊   | 135/200 [01:03<00:30,  2.12it/s]
#  68%|██████▊   | 136/200 [01:03<00:30,  2.11it/s]
#  68%|██████▊   | 137/200 [01:04<00:29,  2.12it/s]
#  69%|██████▉   | 138/200 [01:04<00:29,  2.09it/s]
#  70%|██████▉   | 139/200 [01:05<00:28,  2.13it/s]
#  70%|███████   | 140/200 [01:05<00:28,  2.13it/s]
#  70%|███████   | 141/200 [01:05<00:27,  2.13it/s]
#  71%|███████   | 142/200 [01:06<00:27,  2.09it/s]
#  72%|███████▏  | 143/200 [01:06<00:27,  2.09it/s]
#  72%|███████▏  | 144/200 [01:07<00:26,  2.14it/s]
#  72%|███████▎  | 145/200 [01:07<00:25,  2.14it/s]
#  73%|███████▎  | 146/200 [01:08<00:25,  2.10it/s]
#  74%|███████▎  | 147/200 [01:08<00:25,  2.11it/s]
#  74%|███████▍  | 148/200 [01:09<00:24,  2.14it/s]
#  74%|███████▍  | 149/200 [01:09<00:23,  2.13it/s]
#  75%|███████▌  | 150/200 [01:10<00:23,  2.10it/s]
#  76%|███████▌  | 151/200 [01:10<00:22,  2.14it/s]
#  76%|███████▌  | 152/200 [01:11<00:21,  2.25it/s]
#  76%|███████▋  | 153/200 [01:11<00:19,  2.37it/s]
#  77%|███████▋  | 154/200 [01:11<00:18,  2.45it/s]
#  78%|███████▊  | 155/200 [01:12<00:17,  2.57it/s]
#  78%|███████▊  | 156/200 [01:12<00:17,  2.46it/s]
#  78%|███████▊  | 157/200 [01:12<00:16,  2.58it/s]
#  79%|███████▉  | 158/200 [01:13<00:16,  2.60it/s]
#  80%|███████▉  | 159/200 [01:13<00:15,  2.68it/s]
#  80%|████████  | 160/200 [01:14<00:14,  2.73it/s]
#  80%|████████  | 161/200 [01:14<00:14,  2.70it/s]
#  81%|████████  | 162/200 [01:14<00:14,  2.69it/s]
#  82%|████████▏ | 163/200 [01:15<00:13,  2.73it/s]
#  82%|████████▏ | 164/200 [01:15<00:12,  2.79it/s]
#  82%|████████▎ | 165/200 [01:15<00:12,  2.82it/s]
#  83%|████████▎ | 166/200 [01:16<00:11,  2.85it/s]
#  84%|████████▎ | 167/200 [01:16<00:11,  2.86it/s]
#  84%|████████▍ | 168/200 [01:16<00:11,  2.87it/s]
#  84%|████████▍ | 169/200 [01:17<00:11,  2.60it/s]
#  85%|████████▌ | 170/200 [01:17<00:11,  2.63it/s]
#  86%|████████▌ | 171/200 [01:18<00:10,  2.66it/s]
#  86%|████████▌ | 172/200 [01:18<00:10,  2.73it/s]
#  86%|████████▋ | 173/200 [01:18<00:09,  2.72it/s]
#  87%|████████▋ | 174/200 [01:19<00:09,  2.72it/s]
#  88%|████████▊ | 175/200 [01:19<00:09,  2.77it/s]
#  88%|████████▊ | 176/200 [01:19<00:08,  2.75it/s]
#  88%|████████▊ | 177/200 [01:20<00:08,  2.74it/s]
#  89%|████████▉ | 178/200 [01:20<00:09,  2.38it/s]
#  90%|████████▉ | 179/200 [01:21<00:08,  2.52it/s]
#  90%|█████████ | 180/200 [01:21<00:07,  2.57it/s]
#  90%|█████████ | 181/200 [01:21<00:07,  2.66it/s]
#  91%|█████████ | 182/200 [01:22<00:06,  2.72it/s]
#  92%|█████████▏| 183/200 [01:22<00:07,  2.42it/s]
#  92%|█████████▏| 184/200 [01:23<00:06,  2.46it/s]
#  92%|█████████▎| 185/200 [01:23<00:05,  2.53it/s]
#  93%|█████████▎| 186/200 [01:23<00:05,  2.63it/s]
#  94%|█████████▎| 187/200 [01:24<00:04,  2.70it/s]
#  94%|█████████▍| 188/200 [01:24<00:04,  2.76it/s]
#  94%|█████████▍| 189/200 [01:24<00:04,  2.74it/s]
#  95%|█████████▌| 190/200 [01:25<00:03,  2.79it/s]
#  96%|█████████▌| 191/200 [01:25<00:03,  2.81it/s]
#  96%|█████████▌| 192/200 [01:25<00:02,  2.77it/s]
#  96%|█████████▋| 193/200 [01:26<00:02,  2.80it/s]
#  97%|█████████▋| 194/200 [01:26<00:02,  2.82it/s]
#  98%|█████████▊| 195/200 [01:27<00:01,  2.61it/s]
#  98%|█████████▊| 196/200 [01:27<00:01,  2.69it/s]
#  98%|█████████▊| 197/200 [01:27<00:01,  2.69it/s]
#  99%|█████████▉| 198/200 [01:28<00:00,  2.69it/s]
# 100%|█████████▉| 199/200 [01:28<00:00,  2.75it/s]
# 100%|██████████| 200/200 [01:28<00:00,  2.25it/s]

# %% [markdown]
# ## AI Service Implementation

# %% [markdown]
# ### Helper Functions

# %%
def parse_json_response(text):
    return json.loads(text.strip("```json\n").strip("```"))

def fallback_text_response(text):
    return {"response": text, "confidence": "medium", "source": "direct"}

# Case: no matching content in the vector DB
def default_error_response():
    return {"response": "Please wait while transferring to a human agent.", "confidence": "low", "source": "fallback"}

# Case: quota exceeded (429 Resource Exhausted)
def handle_quota_error(error):
    print("Gemini drained. Wait for 5 minutes...")
    time.sleep(300)

# Case: generic error
def handle_general_error(error):
    return {"response": "Unexpected technical error encountered. Please try later.", "confidence": "low", "source": "error"}

# %% [markdown]
# ### Implementation

# %%
examples = [
    {"q": "How do I reset my password?", "a": "To reset your password, go to the login page and click 'Forgot Password'."},
    {"q": "Where can I find my billing information?", "a": "Billing info is under 'My Account' > 'Billing'."},
    {"q": "Can I change my email address?", "a": "Yes, go to settings and update your email."},
]
example_text = "\n".join([f"User: {ex['q']}\nAgent: {ex['a']}" for ex in examples])

instruction = "Please answer in JSON format with fields 'response' and 'confidence'."

# %%
@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=2, min=10, max=300), retry=retry_if_exception_type(google_exceptions.ResourceExhausted))

def generate_answer(question, context):
    # Fill with prompt
    prompt = f"""
    **Customer Support Guidelines**

    Context:
    {context}

    Example Interactions:
    {example_text}

    Current Query:
    {question}

    {instruction}
    """
    try:
        response = model.generate_content(prompt)
        if not response.text:
            return default_error_response()
        try:
            return parse_json_response(response.text)
        except json.JSONDecodeError:
            return fallback_text_response(response.text)
    except google_exceptions.ResourceExhausted as e:
        handle_quota_error(e)
        raise
    except Exception as e:
      return handle_general_error(e)

# %% [markdown]
# ## Metrics

# %%
def calculate_metrics(generated_text, true_answer):
    metrics = {}

    # Cosine Similarity - focus on semantic similarity
    gen_embedding = get_embedding(generated_text).reshape(1, -1)
    true_embedding = get_embedding(true_answer).reshape(1, -1)
    metrics['cosine_similarity'] = cosine_similarity(gen_embedding, true_embedding)[0][0]

    # BLEU (1-gram to 4-gram) - focus on literal matching
    metrics['bleu'] = sentence_bleu(
        [nltk.word_tokenize(true_answer)],
        nltk.word_tokenize(generated_text)
    )

    # ROUGE (1, 2, L) - Recall
    rouge_scores = rouge_scorer.score(true_answer, generated_text)
    for key in rouge_scores:
        metrics[f"rouge_{key}"] = rouge_scores[key].fmeasure

    return metrics

# %% [markdown]
# ## Results

# %% [markdown]
# Workflow: User Input -> Vector Tranformation -> Search Similar Questions -> Generate Answers -> Metric Evaluation

# %%
def process_single_query(row):
    query = row['prompt']
    true_answer = row['response']
    query_vec = get_embedding(query).reshape(1, -1)

    indices, _ = index.knn_query(query_vec, k=3)
    context = "\n".join(df.iloc[idx]['response'] for idx in indices[0])

    gen_output = generate_answer(query, context)
    gen_text = gen_output.get('response', '')

    if not gen_text:
        return {
            "query": query,
            "generated": gen_output,
            "ground_truth": true_answer,
            "error": "empty_response"
        }

    metrics = calculate_metrics(gen_text, true_answer)

    return {
        "query": query,
        "generated": gen_output,
        "ground_truth": true_answer,
        "metrics": metrics,
        "confidence": gen_output.get('confidence', 'unknown')
    }

results = [process_single_query(row) for _, row in tqdm(df.iterrows(), total=len(df))]
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 1/200 [00:01<06:01,  1.82s/it]
#   1%|          | 2/200 [00:03<05:57,  1.81s/it]
#   2%|▏         | 3/200 [00:05<05:47,  1.76s/it]
#   2%|▏         | 4/200 [00:06<05:22,  1.64s/it]
#   2%|▎         | 5/200 [00:08<05:26,  1.68s/it]
#   3%|▎         | 6/200 [00:10<05:16,  1.63s/it]
#   4%|▎         | 7/200 [00:11<05:07,  1.59s/it]
#   4%|▍         | 8/200 [00:13<05:19,  1.66s/it]
#   4%|▍         | 9/200 [00:15<05:28,  1.72s/it]
#   5%|▌         | 10/200 [00:16<05:26,  1.72s/it]
#   6%|▌         | 11/200 [00:19<05:47,  1.84s/it]
#   6%|▌         | 12/200 [00:21<06:17,  2.01s/it]
#   6%|▋         | 13/200 [00:23<06:11,  1.99s/it]
#   7%|▋         | 14/200 [00:25<06:09,  1.98s/it]
#   8%|▊         | 15/200 [00:26<05:33,  1.80s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.43ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#   8%|▊         | 16/200 [00:27<04:41,  1.53s/it]
#   8%|▊         | 17/200 [00:29<04:41,  1.54s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 230.88ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#   9%|▉         | 18/200 [00:29<03:48,  1.25s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 305.70ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  10%|▉         | 19/200 [00:30<03:15,  1.08s/it]
#  10%|█         | 20/200 [00:34<05:42,  1.90s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 230.15ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  10%|█         | 21/200 [00:35<04:36,  1.54s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 205.39ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  11%|█         | 22/200 [00:35<03:42,  1.25s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.05ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  12%|█▏        | 23/200 [00:36<03:04,  1.04s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 230.53ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  12%|█▏        | 24/200 [00:36<02:39,  1.10it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 205.67ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  12%|█▎        | 25/200 [00:37<02:20,  1.25it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.10ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  13%|█▎        | 26/200 [00:37<02:06,  1.37it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.38ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  14%|█▎        | 27/200 [00:38<01:57,  1.48it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.57ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  14%|█▍        | 28/200 [00:39<02:08,  1.34it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 255.17ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  14%|█▍        | 29/200 [00:39<02:00,  1.42it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.26ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  15%|█▌        | 30/200 [00:40<01:52,  1.51it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 231.31ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  16%|█▌        | 31/200 [00:41<01:47,  1.57it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 230.50ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  16%|█▌        | 32/200 [00:41<01:47,  1.57it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.63ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  16%|█▋        | 33/200 [00:42<01:42,  1.63it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 230.34ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  17%|█▋        | 34/200 [00:42<01:41,  1.63it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 206.27ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  18%|█▊        | 35/200 [00:43<01:38,  1.67it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.15ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  18%|█▊        | 36/200 [00:44<01:37,  1.69it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 209.01ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  18%|█▊        | 37/200 [00:44<01:51,  1.47it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 229.31ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  19%|█▉        | 38/200 [00:45<01:45,  1.53it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 203.79ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  20%|█▉        | 39/200 [00:46<01:41,  1.59it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.60ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  20%|██        | 40/200 [00:46<01:37,  1.64it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 205.28ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  20%|██        | 41/200 [00:47<01:35,  1.67it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.63ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  21%|██        | 42/200 [00:47<01:32,  1.70it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.08ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  22%|██▏       | 43/200 [00:48<01:31,  1.71it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 203.76ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  22%|██▏       | 44/200 [00:48<01:28,  1.76it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.19ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  22%|██▎       | 45/200 [00:49<01:27,  1.77it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.60ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  23%|██▎       | 46/200 [00:49<01:26,  1.77it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 209.60ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  24%|██▎       | 47/200 [00:50<01:26,  1.76it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 203.96ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  24%|██▍       | 48/200 [00:51<01:24,  1.79it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.42ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  24%|██▍       | 49/200 [00:51<01:25,  1.77it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 228.96ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  25%|██▌       | 50/200 [00:52<01:26,  1.73it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.25ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  26%|██▌       | 51/200 [00:52<01:25,  1.75it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 203.93ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  26%|██▌       | 52/200 [00:53<01:24,  1.76it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 205.03ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  26%|██▋       | 53/200 [00:53<01:23,  1.76it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 204.02ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  27%|██▋       | 54/200 [00:54<01:22,  1.77it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 231.25ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  28%|██▊       | 55/200 [00:55<01:22,  1.75it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 206.32ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  28%|██▊       | 56/200 [00:55<01:22,  1.75it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 205.99ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# ...
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  86%|████████▋ | 173/200 [02:52<00:18,  1.50it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 281.67ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  87%|████████▋ | 174/200 [02:52<00:17,  1.49it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 306.90ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  88%|████████▊ | 175/200 [02:53<00:16,  1.47it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 311.74ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  88%|████████▊ | 176/200 [02:54<00:16,  1.45it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 304.55ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  88%|████████▊ | 177/200 [02:55<00:15,  1.45it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 330.27ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  89%|████████▉ | 178/200 [02:55<00:15,  1.44it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 307.89ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  90%|████████▉ | 179/200 [02:56<00:14,  1.44it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 306.15ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  90%|█████████ | 180/200 [02:57<00:13,  1.45it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 305.82ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  90%|█████████ | 181/200 [02:57<00:13,  1.45it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 280.10ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  91%|█████████ | 182/200 [02:58<00:12,  1.47it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 305.38ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  92%|█████████▏| 183/200 [02:59<00:11,  1.47it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 255.88ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  92%|█████████▏| 184/200 [02:59<00:10,  1.50it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 280.04ms
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  92%|█████████▎| 185/200 [03:00<00:10,  1.50it/s]
#  93%|█████████▎| 186/200 [03:01<00:12,  1.13it/s]
#  94%|█████████▎| 187/200 [03:03<00:14,  1.09s/it]
#  94%|█████████▍| 188/200 [03:05<00:14,  1.25s/it]
#  94%|█████████▍| 189/200 [03:06<00:14,  1.33s/it]
#  95%|█████████▌| 190/200 [03:08<00:14,  1.40s/it]/usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
#  96%|█████████▌| 191/200 [03:09<00:13,  1.48s/it]
#  96%|█████████▌| 192/200 [03:12<00:13,  1.71s/it]
#  96%|█████████▋| 193/200 [03:13<00:12,  1.73s/it]
#  97%|█████████▋| 194/200 [03:15<00:09,  1.66s/it]
#  98%|█████████▊| 195/200 [03:17<00:08,  1.74s/it]
#  98%|█████████▊| 196/200 [03:18<00:06,  1.69s/it]
#  98%|█████████▊| 197/200 [03:20<00:05,  1.81s/it]
#  99%|█████████▉| 198/200 [03:22<00:03,  1.85s/it]
# 100%|█████████▉| 199/200 [03:24<00:01,  1.80s/it]
# 100%|██████████| 200/200 [03:26<00:00,  1.03s/it]

# %% [markdown]
# ## Analysis

# %%
def analyze_results(results):
    # Initialize trackers
    analysis = {
        'confidence_calibration': {'high': 0, 'medium': 0, 'low': 0},
        'error_types': {},
        'average_metrics': {
            'cosine_similarity': 0,
            'bleu': 0,
            'rouge_rouge1': 0,
            'rouge_rouge2': 0,
            'rouge_rougeL': 0
        },
        'threshold_counts': {
            'cosine_high': 0,  # >=0.7
            'cosine_medium': 0,  # 0.5-0.7
            'cosine_low': 0,  # <0.5
            'rougeL_high': 0,  # >=0.7
            'rougeL_low': 0   # <0.7
        }
    }

    valid_results = [r for r in results if 'metrics' in r]

    for r in valid_results:
        metrics = r['metrics']
        confidence = r['confidence']

        # Confidence calibration: case with low-quality answer but high labels
        if confidence == 'high':
            analysis['confidence_calibration']['high'] += 1
        elif confidence == 'medium':
            analysis['confidence_calibration']['medium'] += 1
        else:
            analysis['confidence_calibration']['low'] += 1

        for metric in analysis['average_metrics']:
            analysis['average_metrics'][metric] += metrics[metric]

        # Threshold counts for Cosine Similarity
        if metrics['cosine_similarity'] >= 0.7:
            analysis['threshold_counts']['cosine_high'] += 1
        elif metrics['cosine_similarity'] >= 0.5:
            analysis['threshold_counts']['cosine_medium'] += 1
        else:
            analysis['threshold_counts']['cosine_low'] += 1

        if metrics['rouge_rougeL'] >= 0.7:
            analysis['threshold_counts']['rougeL_high'] += 1
        else:
            analysis['threshold_counts']['rougeL_low'] += 1

    # Average Calculattion
    num_valid = len(valid_results)
    for metric in analysis['average_metrics']:
        analysis['average_metrics'][metric] /= num_valid if num_valid > 0 else 1

    # Error analysis
    error_results = [r for r in results if 'error' in r]
    for r in error_results:
        error_type = r['error']
        analysis['error_types'][error_type] = analysis['error_types'].get(error_type, 0) + 1

    return analysis

# %%
analysis = analyze_results(results)

print("\n=== Evaluation Report ===")
print(f"\n**Confidence Distribution:**")
print(f"High: {analysis['confidence_calibration']['high']}")
print(f"Medium: {analysis['confidence_calibration']['medium']}")
print(f"Low: {analysis['confidence_calibration']['low']}")

print("\n**Average Scores:**")
for metric, score in analysis['average_metrics'].items():
    print(f"{metric}: {score:.3f}")

print("\n**Threshold Counts:**")
print(f"Cosine High (>=0.7): {analysis['threshold_counts']['cosine_high']}")
print(f"Cosine Medium (0.5-0.7): {analysis['threshold_counts']['cosine_medium']}")
print(f"Cosine Low (<0.5): {analysis['threshold_counts']['cosine_low']}")
print(f"ROUGE-L High (>=0.7): {analysis['threshold_counts']['rougeL_high']}")
print(f"ROUGE-L Low (<0.7): {analysis['threshold_counts']['rougeL_low']}")

print("\n**Error Analysis:**")
for error, count in analysis['error_types'].items():
    print(f"{error}: {count}")
# Out:
# === Evaluation Report ===
#
# **Confidence Distribution:**
# High: 0
# Medium: 0
# Low: 200
#
# **Average Scores:**
# cosine_similarity: 0.786
# bleu: 0.048
# rouge_rouge1: 0.170
# rouge_rouge2: 0.085
# rouge_rougeL: 0.133
#
# **Threshold Counts:**
# Cosine High (>=0.7): 135
# Cosine Medium (0.5-0.7): 65
# Cosine Low (<0.5): 0
# ROUGE-L High (>=0.7): 1
# ROUGE-L Low (<0.7): 199
#
# **Error Analysis:**

# %% [markdown]
# ## Custom Test

# %%
def test_custom_query(q):
    vec = get_embedding(q).reshape(1, -1)
    indices, _ = index.knn_query(vec, k=3)
    context = "\n".join(df.iloc[idx]['response'] for idx in indices[0])
    response = generate_answer(q, context)
    print(f"\nQuery: {q}\nResponse: {response['response']}\nConfidence: {response['confidence']}")

test_custom_query("Can I use ApplePay?")
test_custom_query("Can I cancel my order?")
test_custom_query("Can I update my mailing address?")
# Out:
# Query: Can I use ApplePay?
# Response: Yes, we accept Apple Pay as a payment method.  However, availability may depend on your location and the specific product or service you are purchasing.  If you encounter any issues, please let me know.
# Confidence: 0.95
#
# Query: Can I cancel my order?
# Response: Yes, you can cancel your order.  To do so, please follow these steps:
#
# 1. Log in to your {{Online Company Portal Info}} using your credentials.
# 2. Navigate to the '{{Online Order Interaction}}' section.
# 3. Locate the order with number {{Order Number}} and click on it.
# 4. Select the '{{Online Order Interaction}}' option to initiate the cancellation.
# 5. Follow any additional instructions provided by the system.
#
# If you encounter any problems, please contact us during {{Customer Support Hours}} at {{Customer Support Phone Number}} or use the Live Chat feature on our {{Website URL}}.
# Confidence: 0.95
#
# Query: Can I update my mailing address?
# Response: Yes, you can update your mailing address. You can do this in a few ways:
#
# 1. **Through our website:** Log in to your account, go to 'My Account', and find the option to edit your shipping address.
# 2. **Contacting customer support:** Call us at [phone number] or email us at [email address]. We'll be happy to assist you.
# Confidence: 0.95
